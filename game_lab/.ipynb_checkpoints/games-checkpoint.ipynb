# %% [markdown]
# # Games
#
#  * Формулирование бизнес-задачи. Что вы хотите сделать? Её перевод на язык машинного обучение, выбор и обоснование метрик качества.
#  * Описание данных, их визуальный анализ.
#  * Предобработка данных. Чётко опишите какую именно предобработку вам необходимо сделать, а главное поясните зачем. Попробуйте сварить в ходе предобработки новые объясняющие переменные, которые могут помочь в решении задачи.
#  * Выберете несколько моделей, которые могли бы вам помочь в решении поставленной задачи. Проведите моделирование.
#  * Постарайтесь достичь максимального качества при моделировании.

# %% [markdown]
# # start
#
# Мы попытаемся найти зависимости продаж между регионами и создать модель которая предскажет их.
#
# Для начала импортируем данные и выполним первичный анализ.

# %%
import numpy as np
import matplotlib.pyplot as plt
import pandas as pd
# %matplotlib inline 
import seaborn as sns
sns.set_style('dark')

df = pd.read_csv('vgsales.csv')
df.head()
# Out:
#    Rank                      Name Platform    Year         Genre Publisher  \
# 0     1                Wii Sports      Wii  2006.0        Sports  Nintendo
# 1     2         Super Mario Bros.      NES  1985.0      Platform  Nintendo
# 2     3            Mario Kart Wii      Wii  2008.0        Racing  Nintendo
# 3     4         Wii Sports Resort      Wii  2009.0        Sports  Nintendo
# 4     5  Pokemon Red/Pokemon Blue       GB  1996.0  Role-Playing  Nintendo
#
#    NA_Sales  EU_Sales  JP_Sales  Other_Sales  Global_Sales
# 0     41.49     29.02      3.77         8.46         82.74
# 1     29.08      3.58      6.81         0.77         40.24
# 2     15.85     12.88      3.79         3.31         35.82
# 3     15.75     11.01      3.28         2.96         33.00
# 4     11.27      8.89     10.22         1.00         31.37

# %% [markdown]
# **Посмотрим информацию о фичах.**

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 16598 entries, 0 to 16597
# Data columns (total 11 columns):
# Rank            16598 non-null int64
# Name            16598 non-null object
# Platform        16598 non-null object
# Year            16327 non-null float64
# Genre           16598 non-null object
# Publisher       16540 non-null object
# NA_Sales        16598 non-null float64
# EU_Sales        16598 non-null float64
# JP_Sales        16598 non-null float64
# Other_Sales     16598 non-null float64
# Global_Sales    16598 non-null float64
# dtypes: float64(6), int64(1), object(4)
# memory usage: 1.4+ MB

# %%
df.describe()
# Out:
#                Rank          Year      NA_Sales      EU_Sales      JP_Sales  \
# count  16598.000000  16327.000000  16598.000000  16598.000000  16598.000000
# mean    8300.605254   2006.406443      0.264667      0.146652      0.077782
# std     4791.853933      5.828981      0.816683      0.505351      0.309291
# min        1.000000   1980.000000      0.000000      0.000000      0.000000
# 25%     4151.250000   2003.000000      0.000000      0.000000      0.000000
# 50%     8300.500000   2007.000000      0.080000      0.020000      0.000000
# 75%    12449.750000   2010.000000      0.240000      0.110000      0.040000
# max    16600.000000   2020.000000     41.490000     29.020000     10.220000
#
#         Other_Sales  Global_Sales
# count  16598.000000  16598.000000
# mean       0.048063      0.537441
# std        0.188588      1.555028
# min        0.000000      0.010000
# 25%        0.000000      0.060000
# 50%        0.010000      0.170000
# 75%        0.040000      0.470000
# ...

# %% [markdown]
# **Выведем количество игр относительно платформ**

# %%
df['Platform'].value_counts()
# Out:
# DS      2163
# PS2     2161
# PS3     1329
# Wii     1325
# X360    1265
# PSP     1213
# PS      1196
# PC       960
# XB       824
# GBA      822
# GC       556
# 3DS      509
# PSV      413
# PS4      336
# N64      319
# SNES     239
# XOne     213
# SAT      173
# WiiU     143
# 2600     133
# NES       98
# GB        98
# DC        52
# GEN       27
# NG        12
# SCD        6
# WS         6
# 3DO        3
# TG16       2
# GG         1
# PCFX       1
# Name: Platform, dtype: int64

# %% [markdown]
# **Выведем количество игр относительно жанров**

# %%
df['Genre'].value_counts()
# Out:
# Action          3316
# Sports          2346
# Misc            1739
# Role-Playing    1488
# Shooter         1310
# Adventure       1286
# Racing          1249
# Platform         886
# Simulation       867
# Fighting         848
# Strategy         681
# Puzzle           582
# Name: Genre, dtype: int64

# %% [markdown]
# **Среднее количество продаж в Северной Америке, Европе, Японии, других и во всем мире**

# %%
sales_continent = ['NA_Sales','EU_Sales','JP_Sales','Other_Sales','Global_Sales']

for i in sales_continent:
    print(i,end=" -->> ")
    print(dataset[i].mean(),end=" миллионов")
    print("\n")
# Out:
# NA_Sales -->> 0.26466742981082064 миллионов
#
# EU_Sales -->> 0.14665200626581515 миллионов
#
# JP_Sales -->> 0.077781660441017 миллионов
#
# Other_Sales -->> 0.0480630196409206 миллионов
#
# Global_Sales -->> 0.5374406555006628 миллионов

# %% [markdown]
# **Для улучшения анализа и визуализации было бы лучше избавиться от игр с издателями, которые опубликовали менее 50 игр и платформ с менее чем 90 играми. Издатели с менее чем 50 играми и платформы с меньше чем 90 играми  будут переименованы в "Other".**

# %%
for i in df['Publisher'].unique():
    if df['Publisher'][df['Publisher'] == i].count() < 50:
        df['Publisher'][df['Publisher'] == i] = 'Other'
        
for i in df['Platform'].unique():
    if df['Platform'][df['Platform'] == i].count() < 90:
        df['Platform'][df['Platform'] == i] = 'Other'
# Out:
# /home/serveruser/.local/lib/python3.5/site-packages/ipykernel_launcher.py:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   This is separate from the ipykernel package so we can avoid doing imports until
# /home/serveruser/.local/lib/python3.5/site-packages/ipykernel_launcher.py:7: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   import sys

# %% [markdown]
# **Посмотрим что поменялось**

# %%
df['Publisher'].value_counts()
# Out:
# Other                                     3342
# Electronic Arts                           1351
# Activision                                 975
# Namco Bandai Games                         932
# Ubisoft                                    921
# Konami Digital Entertainment               832
# THQ                                        715
# Nintendo                                   703
# Sony Computer Entertainment                683
# Sega                                       639
# Take-Two Interactive                       413
# Capcom                                     381
# Atari                                      363
# Tecmo Koei                                 338
# Square Enix                                233
# Warner Bros. Interactive Entertainment     232
# Disney Interactive Studios                 218
# Unknown                                    203
# Eidos Interactive                          198
# Midway Games                               198
# ...

# %%
df['Platform'].value_counts()
# Out:
# DS       2163
# PS2      2161
# PS3      1329
# Wii      1325
# X360     1265
# PSP      1213
# PS       1196
# PC        960
# XB        824
# GBA       822
# GC        556
# 3DS       509
# PSV       413
# PS4       336
# N64       319
# SNES      239
# XOne      213
# SAT       173
# WiiU      143
# 2600      133
# Other     110
# NES        98
# GB         98
# Name: Platform, dtype: int64

# %% [markdown]
# **Теперь после очистки построим графики**

# %%
df['Publisher'].value_counts(sort=False).plot(kind='barh',figsize=(14,14))

# %%
df['Platform'].value_counts(sort=False).plot(kind='barh',figsize=(14,14))

# %% [markdown]
# **Построим график по жанрам**

# %%
sns.factorplot('Genre',data=df,kind='count',size=10)

# %% [markdown]
# **Построим график частоты жанров в зависимости от платформы**

# %%
for i in dataset['Platform'].unique():
    dataset['Genre'][dataset['Platform'] == i].value_counts().plot(kind='line',label=i, figsize=(24,18), grid=True)
plt.legend(bbox_to_anchor=(0., 1.02, 1., .102), loc=3, ncol=20, borderaxespad=0.)
plt.xticks(np.arange(12), tuple(dataset['Genre'].unique()))
plt.tight_layout()
plt.show()

# %% [markdown]
# **Построим график игр имеющих более 1 миллиона копий, проданных в Свереной Америке и сгруппируем их по платформам**

# %%
df.index.name = 'Index'

# %%
platform_name = []
platform_frequency = []
for i in df['Platform'].unique():
    platform_name.append(i)
    platform_frequency.append(df['Name'][df['NA_Sales'] > 1.0][df['Platform'] == i].count())
plat = pd.DataFrame()
plat["Name"] = platform_name
plat["Frequency"] = platform_frequency
plat
# Out:
#      Name  Frequency
# 0     Wii         81
# 1     NES         20
# 2      GB         21
# 3      DS         54
# 4    X360        130
# 5     PS3         84
# 6     PS2        146
# 7    SNES         19
# 8     GBA         30
# 9     3DS         13
# 10    PS4         27
# 11    N64         35
# 12     PS         87
# 13     XB         22
# 14     PC         31
# 15   2600         24
# 16    PSP         10
# 17   XOne         22
# 18     GC         19
# 19   WiiU          8
# 20  Other         12
# 21    PSV          0
# 22    SAT          0

# %% [markdown]
# **С помощью полученного выше датафрейма можем построить круговую диаграмму **

# %%
plat.plot(kind='pie',y='Frequency',labels=plat['Name'],legend=False,figsize=(16,16))

# %% [markdown]
# **Посмотрим корелляцию между регионами**

# %%
corr_1 = []
corr_2 = []
corr_res = []
sales_list = ['NA_Sales','EU_Sales','JP_Sales','Other_Sales','Global_Sales']
for i in sales_list:
    for j in sales_list:
        corr_1.append(i)
        corr_2.append(j)
        corr_res.append(dataset[i].corr(dataset[j]))
corr_data = pd.DataFrame(
    {'Corr_1': corr_1,
     'Corr_2': corr_2,
     'Correlation': corr_res
    })
corr_data = corr_data.pivot(values='Correlation',index='Corr_1',columns='Corr_2')

corr_data
# Out:
# Corr_2        EU_Sales  Global_Sales  JP_Sales  NA_Sales  Other_Sales
# Corr_1
# EU_Sales      1.000000      0.902836  0.435584  0.767727     0.726385
# Global_Sales  0.902836      1.000000  0.611816  0.941047     0.748331
# JP_Sales      0.435584      0.611816  1.000000  0.449787     0.290186
# NA_Sales      0.767727      0.941047  0.449787  1.000000     0.634737
# Other_Sales   0.726385      0.748331  0.290186  0.634737     1.000000

# %%
sns.heatmap(corr_data)
